# %% [markdown]
# <a href="https://colab.research.google.com/github/Holmes-Alan/PUFM/blob/main/PUFM_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Holmes-Alan/Enhanced_PUFM.git
# Out:
# Cloning into 'PUFM'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 170 (delta 23), reused 6 (delta 1), pack-reused 113 (from 2)
# Receiving objects: 100% (170/170), 54.26 MiB | 16.95 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# %cd Enhanced_PUFM/
# !ls

# %%
# !pip install torch numpy open3d einops scikit-learn tqdm h5py plyfile

# %%
# %cd models/pointops
# !python setup.py install
# %cd ../../Chamfer3D
# !python setup.py install
# %cd ../emd_assignment
# !python setup.py install
# %cd ../

# %%
# 1. 4X on one single point cloud
# !python demo_epufm.py --test_input_path example/small_pc --up_rate 4
# result should be in output/pcd

# %%
# 2. 4X for large-scale lidar point cloud
# !python demo_epufm_large_pc.py --dataset pugan --test_input_path example/large_pc --up_rate 4
